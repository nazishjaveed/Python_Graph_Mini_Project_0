# %% [markdown]
# # 📊 Create Bullet Chart Using Python 🐍

# %%
import matplotlib.pyplot as plt

# 📊 Data for the bullet chart
performance = 70  # 🎯 Actual performance
target = 85       # 🎯 Target value
ranges = [30, 60, 90]  # 📏 Ranges for benchmarks (e.g., low, medium, high)

# 🛠️ Create the bullet chart
plt.figure(figsize=(8, 2))

# ➖ Plot the benchmark ranges as horizontal bars
plt.barh(0, ranges[2], color='lightgray', height=0.5, label='High 🚀')
plt.barh(0, ranges[1], color='gray', height=0.5, label='Medium ⚙️')
plt.barh(0, ranges[0], color='darkgray', height=0.5, label='Low 🐢')

# 🔵 Plot the actual performance
plt.barh(0, performance, color='blue', height=0.3, label='Performance 💼')

# 🔴 Plot the target as a vertical line
plt.axvline(target, color='red', linestyle='--', linewidth=2, label='Target 🎯')

# 🎨 Customize the chart
plt.title('📈 Bullet Chart', fontsize=14)
plt.yticks([])  # ❌ Remove y-axis ticks
plt.xticks(range(0, 101, 10))  # 📏 X-axis ticks
plt.xlabel('Value 📊', fontsize=12)
plt.legend(loc='upper right', fontsize=10)

# ➕ Add gridlines
plt.grid(axis='x', linestyle='--', alpha=0.7)

# 👀 Show the chart
plt.tight_layout()
plt.show()
