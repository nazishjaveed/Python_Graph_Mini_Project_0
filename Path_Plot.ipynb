# %% [markdown]
# # 🛤️ Create Path Plot Using Python

# %%
import numpy as np
import matplotlib.pyplot as plt

# 🎲 Generate random points to simulate a path
np.random.seed(42)  # 🧬 For reproducibility
n_points = 10
x = np.random.rand(n_points)  # 📍 Random x coordinates
y = np.random.rand(n_points)  # 📍 Random y coordinates

# 🛣️ Plot the path
plt.figure(figsize=(8, 6))
plt.plot(x, y, marker='o', color='b', linestyle='-', markersize=8, label="Path 🚶‍♂️")

# 🧾 Customize the plot
plt.title("Path Plot 📈", fontsize=16)
plt.xlabel("X ➡️", fontsize=12)
plt.ylabel("Y ⬆️", fontsize=12)
plt.legend()

# 👁️ Show the plot
plt.tight_layout()
plt.show()
