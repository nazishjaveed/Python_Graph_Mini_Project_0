# %% [markdown]
# # 📊 Create Grouped Bar Chart Using Python

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data
categories = ['Category 1', 'Category 2', 'Category 3']
group1 = [5, 7, 9]
group2 = [6, 8, 10]
group3 = [4, 6, 8]

# Number of categories
x = np.arange(len(categories))

# Bar width
bar_width = 0.25

# Create the grouped bar chart
plt.figure(figsize=(8, 6))
plt.bar(x - bar_width, group1, width=bar_width, label='Group 1', color='blue')
plt.bar(x, group2, width=bar_width, label='Group 2', color='green')
plt.bar(x + bar_width, group3, width=bar_width, label='Group 3', color='orange')

# Add labels, title, and legend
plt.xlabel('Categories', fontsize=12)
plt.ylabel('Values', fontsize=12)
plt.title('Grouped Bar Chart', fontsize=16)
plt.xticks(x, categories)
plt.legend()

# Add gridlines (optional)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
