# %% [markdown]
# # Create The Chart Pareto Using Python 📊

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {'Category': ['A', 'B', 'C', 'D', 'E'],
        'Value': [50, 30, 20, 15, 10]}

# Create a DataFrame
df = pd.DataFrame(data)

# Sort data by 'Value' in descending order
df = df.sort_values(by='Value', ascending=False)

# Calculate cumulative percentage
df['Cumulative Percentage'] = df['Value'].cumsum() / df['Value'].sum() * 100

# Plot Pareto Chart
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart (left y-axis)
ax1.bar(df['Category'], df['Value'], color='skyblue', label='Value')
ax1.set_xlabel('Category', fontsize=12)
ax1.set_ylabel('Value', fontsize=12)
ax1.tick_params(axis='y', labelsize=10)
ax1.grid(alpha=0.3)

# Line chart (right y-axis)
ax2 = ax1.twinx()
ax2.plot(df['Category'], df['Cumulative Percentage'], color='red', marker='o', label='Cumulative %')
ax2.set_ylabel('Cumulative Percentage (%)', fontsize=12)
ax2.tick_params(axis='y', labelsize=10)

# Add thresholds and title
for i, txt in enumerate(df['Cumulative Percentage']):
    ax2.annotate(f'{txt:.1f}%', (df['Category'].iloc[i], txt), textcoords="offset points", xytext=(0, 10), ha='center')

plt.title('Pareto Chart 📊', fontsize=16)

# Add legends
ax1.legend(loc='upper left')
ax2.legend(loc='upper right')

plt.tight_layout()
plt.show()
