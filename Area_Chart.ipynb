# %% [markdown]
# # Create Area Chart Using Python 🐍📈🌈

# %%
import matplotlib.pyplot as plt
import numpy as np

# Sample data for the area chart 📈
x = np.linspace(0, 10, 100)  # X values from 0 to 10 with 100 points ➡️
y = np.sin(x)  # Y values as the sine of x 🌊

# Create the area chart 🖼️
plt.figure(figsize=(8, 6))  # Set the figure size 📏
plt.fill_between(x, y, color="skyblue", alpha=0.4)  # Area chart (fill the area under the curve) 🎨
plt.plot(x, y, color="Slateblue", alpha=0.6)  # Plot the line on top of the area ✏️

# Add labels and title 🏷️
plt.xlabel("X Axis ➡️")
plt.ylabel("Y Axis ⬆️")
plt.title("Area Chart Example 📊")

# Show the plot 👀
plt.show()
