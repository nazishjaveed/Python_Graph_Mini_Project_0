# %% [markdown]
# # 📊 Create Stacked Bar Chart Using Python

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Sample Data: Replace with your dataset
data = {
    '📘 Category A': [5, 7, 10, 4],
    '📗 Category B': [3, 2, 4, 8],
    '📙 Category C': [6, 9, 7, 3]
}

# Create a DataFrame
df = pd.DataFrame(data, index=['🔹 Item 1', '🔸 Item 2', '🔹 Item 3', '🔸 Item 4'])

# Stacked Bar Chart
df.plot(kind='bar', stacked=True, figsize=(10, 6), colormap='viridis')

# Add titles and labels with emojis
plt.title('📊 Stacked Bar Chart Example', fontsize=16, fontweight='bold')
plt.xlabel('🧾 Items', fontsize=12)
plt.ylabel('📈 Values', fontsize=12)

# Show the plot
plt.tight_layout()
plt.show()
